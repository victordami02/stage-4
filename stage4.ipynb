# %%
pwd
# Out:
# '/Users/mac/Downloads'

# %%
import sys

sys.path.append('../src')
sys.path.append('../tests')

# %%
import os
import gc

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, History

import data_helper
from data_helper import AmazonPreprocessor
from kaggle_data.downloader import KaggleDataDownloader

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/4c/y8mf6l556c988n46dnt19ybh0000gn/T/ipykernel_31190/3482464758.py in <module>
#       5 import pandas as pd
#       6 import seaborn as sns
# ----> 7 import tensorflow as tf
#       8 import matplotlib.pyplot as plt
#       9 import matplotlib.image as mpimg
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
conda install tensorflow
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/mac/opt/anaconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2022.10  |           py39_2          69 KB
#     _tflow_select-2.2.0        |            eigen           3 KB
#     abseil-cpp-20211102.0      |       he9d5cce_0         933 KB
#     absl-py-1.4.0              |   py39hecd8cb5_0         185 KB
#     aiohttp-3.8.3              |   py39h6c40b1e_0         428 KB
#     aiosignal-1.2.0            |     pyhd3eb1b0_0          12 KB
#     anaconda-custom            |           py39_2          13 KB
#     anaconda-navigator-2.4.2   |   py39hecd8cb5_0         6.8 MB
#     astunparse-1.6.3           |             py_0          17 KB
#     async-timeout-4.0.2        |   py39hecd8cb5_0          13 KB
#     blinker-1.4                |   py39hecd8cb5_0          23 KB
#     boltons-23.0.0             |   py39hecd8cb5_0         423 KB
#     ca-certificates-2023.05.30 |       hecd8cb5_0         121 KB
#     cachetools-4.2.2           |     pyhd3eb1b0_0          13 KB
#     certifi-2023.5.7           |   py39hecd8cb5_0         153 KB
#     conda-23.5.2               |   py39hecd8cb5_0         1.0 MB
#     curl-7.87.0                |       h6c40b1e_0          83 KB
#     daal4py-2023.1.1           |   py39h01d92e1_0        10.8 MB
#     dal-2023.1.1               |   ha357a0b_48680        25.0 MB
#     flatbuffers-2.0.0          |       h23ab428_0         925 KB
#     frozenlist-1.3.3           |   py39h6c40b1e_0          41 KB
#     gast-0.4.0                 |     pyhd3eb1b0_0          13 KB
#     google-auth-2.6.0          |     pyhd3eb1b0_0          83 KB
#     google-auth-oauthlib-0.4.4 |     pyhd3eb1b0_0          18 KB
#     google-pasta-0.2.0         |     pyhd3eb1b0_0          46 KB
#     grpc-cpp-1.46.1            |       h64d96ca_1         2.8 MB
#     grpcio-1.42.0              |   py39ha29bfda_0         1.9 MB
#     jsonpatch-1.32             |     pyhd3eb1b0_0          15 KB
#     jsonpointer-2.1            |     pyhd3eb1b0_0           9 KB
#     keras-2.10.0               |   py39hecd8cb5_0         1.6 MB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     libcurl-7.87.0             |       ha585b31_0         338 KB
#     libprotobuf-3.20.3         |       hfff2838_0         2.0 MB
#     mpich-4.1.1                |       hc226d05_0        23.8 MB
#     multidict-6.0.2            |   py39hca72f7f_0          45 KB
#     oauthlib-3.2.2             |   py39hecd8cb5_0         211 KB
#     openssl-1.1.1u             |       hca72f7f_0         3.4 MB
#     opt_einsum-3.3.0           |     pyhd3eb1b0_1          57 KB
#     packaging-23.0             |   py39hecd8cb5_0          71 KB
#     protobuf-3.20.3            |   py39hcec6c5f_0         297 KB
#     python-flatbuffers-2.0     |     pyhd3eb1b0_0          34 KB
#     re2-2022.04.01             |       he9d5cce_0         179 KB
#     requests-oauthlib-1.3.0    |             py_0          23 KB
#     rsa-4.7.2                  |     pyhd3eb1b0_1          28 KB
#     scikit-learn-intelex-2023.1.1|   py39hecd8cb5_0         114 KB
#     sqlite-3.40.1              |       h880c91c_0         1.2 MB
#     tensorboard-2.10.0         |   py39hecd8cb5_0         5.6 MB
#     tensorboard-data-server-0.6.1|   py39h7242b5c_0         2.8 MB
#     tensorboard-plugin-wit-1.6.0|             py_0         630 KB
#     tensorflow-2.10.0          |eigen_py39h2f7e057_0           4 KB
#     tensorflow-base-2.10.0     |eigen_py39h61e1807_0       103.4 MB
#     tensorflow-estimator-2.10.0|   py39hecd8cb5_0         484 KB
#     termcolor-2.1.0            |   py39hecd8cb5_0          12 KB
#     wheel-0.35.1               |     pyhd3eb1b0_0          38 KB
#     yarl-1.8.1                 |   py39hca72f7f_0          82 KB
#     ------------------------------------------------------------
#                                            Total:       198.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2022.10-py39_2
#   _tflow_select      pkgs/main/osx-64::_tflow_select-2.2.0-eigen
#   abseil-cpp         pkgs/main/osx-64::abseil-cpp-20211102.0-he9d5cce_0
#   absl-py            pkgs/main/osx-64::absl-py-1.4.0-py39hecd8cb5_0
#   aiohttp            pkgs/main/osx-64::aiohttp-3.8.3-py39h6c40b1e_0
#   aiosignal          pkgs/main/noarch::aiosignal-1.2.0-pyhd3eb1b0_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   async-timeout      pkgs/main/osx-64::async-timeout-4.0.2-py39hecd8cb5_0
#   blinker            pkgs/main/osx-64::blinker-1.4-py39hecd8cb5_0
#   boltons            pkgs/main/osx-64::boltons-23.0.0-py39hecd8cb5_0
#   cachetools         pkgs/main/noarch::cachetools-4.2.2-pyhd3eb1b0_0
#   flatbuffers        pkgs/main/osx-64::flatbuffers-2.0.0-h23ab428_0
#   frozenlist         pkgs/main/osx-64::frozenlist-1.3.3-py39h6c40b1e_0
#   gast               pkgs/main/noarch::gast-0.4.0-pyhd3eb1b0_0
#   google-auth        pkgs/main/noarch::google-auth-2.6.0-pyhd3eb1b0_0
#   google-auth-oauth~ pkgs/main/noarch::google-auth-oauthlib-0.4.4-pyhd3eb1b0_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0
#   grpc-cpp           pkgs/main/osx-64::grpc-cpp-1.46.1-h64d96ca_1
#   grpcio             pkgs/main/osx-64::grpcio-1.42.0-py39ha29bfda_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd3eb1b0_0
#   jsonpointer        pkgs/main/noarch::jsonpointer-2.1-pyhd3eb1b0_0
#   keras              pkgs/main/osx-64::keras-2.10.0-py39hecd8cb5_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   libprotobuf        pkgs/main/osx-64::libprotobuf-3.20.3-hfff2838_0
#   multidict          pkgs/main/osx-64::multidict-6.0.2-py39hca72f7f_0
#   oauthlib           pkgs/main/osx-64::oauthlib-3.2.2-py39hecd8cb5_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1
#   protobuf           pkgs/main/osx-64::protobuf-3.20.3-py39hcec6c5f_0
#   python-flatbuffers pkgs/main/noarch::python-flatbuffers-2.0-pyhd3eb1b0_0
#   re2                pkgs/main/osx-64::re2-2022.04.01-he9d5cce_0
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0
#   rsa                pkgs/main/noarch::rsa-4.7.2-pyhd3eb1b0_1
#   tensorboard        pkgs/main/osx-64::tensorboard-2.10.0-py39hecd8cb5_0
#   tensorboard-data-~ pkgs/main/osx-64::tensorboard-data-server-0.6.1-py39h7242b5c_0
#   tensorboard-plugi~ pkgs/main/noarch::tensorboard-plugin-wit-1.6.0-py_0
#   tensorflow         pkgs/main/osx-64::tensorflow-2.10.0-eigen_py39h2f7e057_0
#   tensorflow-base    pkgs/main/osx-64::tensorflow-base-2.10.0-eigen_py39h61e1807_0
#   tensorflow-estima~ pkgs/main/osx-64::tensorflow-estimator-2.10.0-py39hecd8cb5_0
#   termcolor          pkgs/main/osx-64::termcolor-2.1.0-py39hecd8cb5_0
#   yarl               pkgs/main/osx-64::yarl-1.8.1-py39hca72f7f_0
#
# The following packages will be UPDATED:
#
#   anaconda-navigator                   2.3.1-py39hecd8cb5_0 --> 2.4.2-py39hecd8cb5_0
#   ca-certificates                     2022.07.19-hecd8cb5_0 --> 2023.05.30-hecd8cb5_0
#   certifi                          2022.9.24-py39hecd8cb5_0 --> 2023.5.7-py39hecd8cb5_0
#   conda              conda-forge::conda-22.11.1-py39h6e949~ --> pkgs/main::conda-23.5.2-py39hecd8cb5_0
#   curl                                    7.84.0-hca72f7f_0 --> 7.87.0-h6c40b1e_0
#   daal4py                           2021.6.0-py39h01d92e1_1 --> 2023.1.1-py39h01d92e1_0
#   dal                                 2021.6.0-haf03e11_929 --> 2023.1.1-ha357a0b_48680
#   libcurl                                 7.84.0-h6dfd666_0 --> 7.87.0-ha585b31_0
#   mpich                                    3.3.2-external_0 --> 4.1.1-hc226d05_0
#   openssl                                 1.1.1q-hca72f7f_0 --> 1.1.1u-hca72f7f_0
#   packaging          pkgs/main/noarch::packaging-21.3-pyhd~ --> pkgs/main/osx-64::packaging-23.0-py39hecd8cb5_0
#   scikit-learn-inte~                2021.6.0-py39hecd8cb5_0 --> 2023.1.1-py39hecd8cb5_0
#   sqlite                                  3.39.3-h707629a_0 --> 3.40.1-h880c91c_0
#   zlib                                    1.2.12-h4dc903c_3 --> 1.2.13-h4dc903c_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2022.10-py39_0 --> custom-py39_2
#   wheel                                 0.37.1-pyhd3eb1b0_0 --> 0.35.1-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
# oauthlib-3.2.2       | 211 KB    |                                       |   0%
# abseil-cpp-20211102. | 933 KB    |                                       |   0%
#
# grpcio-1.42.0        | 1.9 MB    |                                       |   0%
#
#
# yarl-1.8.1           | 82 KB     |                                       |   0%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   |                                       |   0%
#
#
#
#
# aiosignal-1.2.0      | 12 KB     |                                       |   0%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    |                                       |   0%
#
#
#
#
#
#
#
# jsonpatch-1.32       | 15 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# blinker-1.4          | 23 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# multidict-6.0.2      | 45 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# async-timeout-4.0.2  | 13 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# jsonpointer-2.1      | 9 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.8.3        | 428 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# termcolor-2.1.0      | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-3.20.3      | 297 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# flatbuffers-2.0.0    | 925 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-flatbuffers-2 | 34 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rsa-4.7.2            | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# curl-7.87.0          | 83 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# yarl-1.8.1           | 82 KB     | #######2                              |  20%
#
#
# yarl-1.8.1           | 82 KB     | ##############4                       |  39%
# abseil-cpp-20211102. | 933 KB    | 6                                     |   2%
#
#
# yarl-1.8.1           | 82 KB     | #####################6                |  59%
#
#
# yarl-1.8.1           | 82 KB     | ############################9         |  78%
# abseil-cpp-20211102. | 933 KB    | #2                                    |   3%
#
#
# yarl-1.8.1           | 82 KB     | ##################################### | 100%
#
#
# yarl-1.8.1           | 82 KB     | ##################################### | 100%
# abseil-cpp-20211102. | 933 KB    | ##5                                   |   7%
# abseil-cpp-20211102. | 933 KB    | ###1                                  |   9%
# abseil-cpp-20211102. | 933 KB    | ###8                                  |  10%
# abseil-cpp-20211102. | 933 KB    | ####4                                 |  12%
# abseil-cpp-20211102. | 933 KB    | #####7                                |  15%
# abseil-cpp-20211102. | 933 KB    | ######3                               |  17%
# abseil-cpp-20211102. | 933 KB    | #######6                              |  21%
# oauthlib-3.2.2       | 211 KB    | ##################################### | 100%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   |                                       |   0%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | 1                                     |   0%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | 2                                     |   1%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | 3                                     |   1%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | 4                                     |   1%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | 5                                     |   1%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | 6                                     |   2%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | 7                                     |   2%
#
#
#
#
# aiosignal-1.2.0      | 12 KB     | ##################################### | 100%
#
#
#
#
# aiosignal-1.2.0      | 12 KB     | ##################################### | 100%
# abseil-cpp-20211102. | 933 KB    | #########5                            |  26%
# abseil-cpp-20211102. | 933 KB    | ##########7                           |  29%
# abseil-cpp-20211102. | 933 KB    | ###########4                          |  31%
# abseil-cpp-20211102. | 933 KB    | ############                          |  33%
# abseil-cpp-20211102. | 933 KB    | #############3                        |  36%
# abseil-cpp-20211102. | 933 KB    | ##############5                       |  39%
# abseil-cpp-20211102. | 933 KB    | ###############8                      |  43%
# abseil-cpp-20211102. | 933 KB    | ################4                     |  45%
# abseil-cpp-20211102. | 933 KB    | #################7                    |  48%
# abseil-cpp-20211102. | 933 KB    | ###################                   |  51%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | 8                                     |   2%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | 5                                     |   2%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #7                                    |   5%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | 9                                     |   3%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ##8                                   |   8%
#
# grpcio-1.42.0        | 1.9 MB    | 3                                     |   1%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ####                                  |  11%
#
# grpcio-1.42.0        | 1.9 MB    | 6                                     |   2%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #                                     |   3%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ####6                                 |  12%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #####1                                |  14%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #####7                                |  16%
#
# grpcio-1.42.0        | 1.9 MB    | 9                                     |   2%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #                                     |   3%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ######9                               |  19%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #######4                              |  20%
#
# grpcio-1.42.0        | 1.9 MB    | #2                                    |   3%
#
# grpcio-1.42.0        | 1.9 MB    | #5                                    |   4%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ########                              |  22%
#
# grpcio-1.42.0        | 1.9 MB    | #8                                    |   5%
# grpcio-1.42.0        | 1.9 MB    | ##1                                   |   6%
#
# grpcio-1.42.0        | 1.9 MB    | ##7                                   |   7%
#
# grpcio-1.42.0        | 1.9 MB    | ###                                   |   8%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #1                                    |   3%
#
# grpcio-1.42.0        | 1.9 MB    | ###3                                  |   9%
#
# grpcio-1.42.0        | 1.9 MB    | ###6                                  |  10%
#
# grpcio-1.42.0        | 1.9 MB    | ###9                                  |  11%
#
# grpcio-1.42.0        | 1.9 MB    | ####2                                 |  11%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #1                                    |   3%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #2                                    |   3%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #3                                    |   4%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #4                                    |   4%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #4                                    |   4%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #6                                    |   4%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    | ###3                                  |   9%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    | ######6                               |  18%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    | #########9                            |  27%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    | ################5                     |  45%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    | ###################8                  |  54%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    | #######################1              |  63%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    | ##########################4           |  72%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    | #################################1    |  90%
#
#
#
#
#
#
# re2-2022.04.01       | 179 KB    | ##################################### | 100%
# abseil-cpp-20211102. | 933 KB    | ###################6                  |  53%
# abseil-cpp-20211102. | 933 KB    | ####################9                 |  57%
# abseil-cpp-20211102. | 933 KB    | #####################5                |  58%
# abseil-cpp-20211102. | 933 KB    | ######################1               |  60%
# abseil-cpp-20211102. | 933 KB    | #######################4              |  63%
# abseil-cpp-20211102. | 933 KB    | ########################7             |  67%
# abseil-cpp-20211102. | 933 KB    | #########################3            |  69%
# abseil-cpp-20211102. | 933 KB    | ##########################            |  70%
# abseil-cpp-20211102. | 933 KB    | ##########################6           |  72%
# abseil-cpp-20211102. | 933 KB    | ###########################9          |  75%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #6                                    |   4%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #7                                    |   5%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #########2                            |  25%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #########7                            |  26%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ##########9                           |  30%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #8                                    |   5%
#
# grpcio-1.42.0        | 1.9 MB    | ####5                                 |  12%
#
# grpcio-1.42.0        | 1.9 MB    | ####8                                 |  13%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ############                          |  33%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ############6                         |  34%
#
# grpcio-1.42.0        | 1.9 MB    | #####1                                |  14%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #8                                    |   5%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #############2                        |  36%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ##############3                       |  39%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ##############9                       |  40%
#
# grpcio-1.42.0        | 1.9 MB    | #####4                                |  15%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ###############5                      |  42%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ################6                     |  45%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #################8                    |  48%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ##################9                   |  51%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ####################1                 |  54%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #####################2                |  58%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ######################4               |  61%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #######################5              |  64%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ########################7             |  67%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #########################8            |  70%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ###########################           |  73%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ############################1         |  76%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #############################3        |  79%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ##############################4       |  82%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ###############################6      |  85%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ################################7     |  89%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #9                                    |   5%
#
# grpcio-1.42.0        | 1.9 MB    | ######                                |  16%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | #################################9    |  92%
#
# grpcio-1.42.0        | 1.9 MB    | ######3                               |  17%
#
# grpcio-1.42.0        | 1.9 MB    | ######6                               |  18%
#
# grpcio-1.42.0        | 1.9 MB    | ######9                               |  19%
#
# grpcio-1.42.0        | 1.9 MB    | #######2                              |  20%
#
# grpcio-1.42.0        | 1.9 MB    | #######5                              |  20%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #9                                    |   5%
#
# grpcio-1.42.0        | 1.9 MB    | #######8                              |  21%
#
# grpcio-1.42.0        | 1.9 MB    | ########1                             |  22%
#
# grpcio-1.42.0        | 1.9 MB    | ########4                             |  23%
#
# grpcio-1.42.0        | 1.9 MB    | #########                             |  24%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##                                    |   5%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##1                                   |   6%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##1                                   |   6%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##2                                   |   6%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##4                                   |   6%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##4                                   |   7%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##5                                   |   7%
# daal4py-2023.1.1     | 10.8 MB   | ##6                                   |   7%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##6                                   |   7%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##7                                   |   8%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##8                                   |   8%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##9                                   |   8%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###                                   |   8%
#
#
#
#
#
#
#
# jsonpatch-1.32       | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# jsonpatch-1.32       | 15 KB     | ##################################### | 100%
# abseil-cpp-20211102. | 933 KB    | ############################5         |  77%
# abseil-cpp-20211102. | 933 KB    | #############################8        |  81%
# abseil-cpp-20211102. | 933 KB    | ##############################4       |  82%
# abseil-cpp-20211102. | 933 KB    | ###############################       |  84%
# abseil-cpp-20211102. | 933 KB    | ###############################7      |  86%
# abseil-cpp-20211102. | 933 KB    | ################################3     |  87%
# abseil-cpp-20211102. | 933 KB    | #################################6    |  91%
# abseil-cpp-20211102. | 933 KB    | ##################################8   |  94%
# abseil-cpp-20211102. | 933 KB    | ###################################5  |  96%
# abseil-cpp-20211102. | 933 KB    | ####################################7 |  99%
# abseil-cpp-20211102. | 933 KB    | ##################################### | 100%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###2                                  |   9%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ###################################   |  95%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ###################################6  |  96%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ####################################8 |  99%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###3                                  |   9%
#
# grpcio-1.42.0        | 1.9 MB    | #########3                            |  25%
#
#
#
#
#
# conda-23.5.2         | 1.0 MB    | ##################################### | 100%
#
# grpcio-1.42.0        | 1.9 MB    | #########9                            |  27%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###3                                  |   9%
#
# grpcio-1.42.0        | 1.9 MB    | ##########5                           |  28%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###4                                  |   9%
#
# grpcio-1.42.0        | 1.9 MB    | ###########4                          |  31%
#
# grpcio-1.42.0        | 1.9 MB    | ############                          |  33%
#
# grpcio-1.42.0        | 1.9 MB    | ############6                         |  34%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###4                                  |   9%
#
# grpcio-1.42.0        | 1.9 MB    | #############2                        |  36%
#
# grpcio-1.42.0        | 1.9 MB    | #############8                        |  37%
#
# grpcio-1.42.0        | 1.9 MB    | ##############7                       |  40%
#
# grpcio-1.42.0        | 1.9 MB    | ###############3                      |  42%
#
# grpcio-1.42.0        | 1.9 MB    | ###############9                      |  43%
#
# grpcio-1.42.0        | 1.9 MB    | ################5                     |  45%
#
# grpcio-1.42.0        | 1.9 MB    | #################1                    |  46%
#
# grpcio-1.42.0        | 1.9 MB    | #################7                    |  48%
#
# grpcio-1.42.0        | 1.9 MB    | ##################3                   |  50%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###5                                  |  10%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###6                                  |  10%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###6                                  |  10%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###7                                  |  10%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###8                                  |  11%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####                                  |  11%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####1                                 |  11%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####2                                 |  12%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####3                                 |  12%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####4                                 |  12%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####5                                 |  12%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ####8                                 |  13%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ##############6                       |  40%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ########################4             |  66%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ##################################2   |  93%
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# blinker-1.4          | 23 KB     | ##########################1           |  71%
#
#
#
#
#
#
#
#
#
# blinker-1.4          | 23 KB     | ##################################### | 100%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####6                                 |  13%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####7                                 |  13%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####8                                 |  13%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ####9                                 |  13%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####                                 |  14%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####1                                |  14%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####2                                |  14%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####3                                |  15%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####4                                |  15%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####6                                |  15%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####7                                |  15%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####8                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####8                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####9                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #####9                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######1                               |  17%
#
# grpcio-1.42.0        | 1.9 MB    | ##################9                   |  51%
#
# grpcio-1.42.0        | 1.9 MB    | ###################2                  |  52%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
# multidict-6.0.2      | 45 KB     | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
# multidict-6.0.2      | 45 KB     | ##########################4           |  71%
#
#
#
#
#
#
#
#
#
#
# multidict-6.0.2      | 45 KB     | ##################################### | 100%
# daal4py-2023.1.1     | 10.8 MB   | ######2                               |  17%
#
# grpcio-1.42.0        | 1.9 MB    | ###################8                  |  54%
#
# grpcio-1.42.0        | 1.9 MB    | ####################4                 |  55%
#
# grpcio-1.42.0        | 1.9 MB    | ####################7                 |  56%
#
# grpcio-1.42.0        | 1.9 MB    | #####################3                |  58%
#
# grpcio-1.42.0        | 1.9 MB    | #####################6                |  59%
#
# grpcio-1.42.0        | 1.9 MB    | #####################9                |  59%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######3                               |  17%
#
# grpcio-1.42.0        | 1.9 MB    | ######################2               |  60%
#
# grpcio-1.42.0        | 1.9 MB    | ######################5               |  61%
#
# grpcio-1.42.0        | 1.9 MB    | ######################8               |  62%
#
# grpcio-1.42.0        | 1.9 MB    | #######################1              |  63%
#
# grpcio-1.42.0        | 1.9 MB    | #######################4              |  63%
#
# grpcio-1.42.0        | 1.9 MB    | #######################7              |  64%
#
# grpcio-1.42.0        | 1.9 MB    | ########################              |  65%
#
# grpcio-1.42.0        | 1.9 MB    | ########################3             |  66%
#
# grpcio-1.42.0        | 1.9 MB    | ########################6             |  67%
#
# grpcio-1.42.0        | 1.9 MB    | ########################9             |  68%
#
# grpcio-1.42.0        | 1.9 MB    | #########################3            |  68%
#
# grpcio-1.42.0        | 1.9 MB    | #########################6            |  69%
#
# grpcio-1.42.0        | 1.9 MB    | #########################9            |  70%
#
# grpcio-1.42.0        | 1.9 MB    | ##########################2           |  71%
#
# grpcio-1.42.0        | 1.9 MB    | ##########################5           |  72%
#
# grpcio-1.42.0        | 1.9 MB    | ###########################1          |  73%
#
# grpcio-1.42.0        | 1.9 MB    | ###########################4          |  74%
#
# grpcio-1.42.0        | 1.9 MB    | ###########################7          |  75%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######4                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######4                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######5                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######6                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######7                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######7                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######8                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######8                               |  19%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######9                               |  19%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ######9                               |  19%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######                               |  19%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######                               |  19%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######1                              |  19%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######2                              |  19%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######3                              |  20%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# async-timeout-4.0.2  | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# async-timeout-4.0.2  | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #4                                    |   4%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######5                              |  20%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######5                              |  20%
# daal4py-2023.1.1     | 10.8 MB   | #######6                              |  21%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######7                              |  21%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######7                              |  21%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######8                              |  21%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######8                              |  21%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #######9                              |  21%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########                              |  22%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########1                             |  22%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########1                             |  22%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########2                             |  22%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########2                             |  22%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########3                             |  23%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########4                             |  23%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########5                             |  23%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########5                             |  23%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########6                             |  24%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########7                             |  24%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########8                             |  24%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########8                             |  24%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ########9                             |  24%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########                             |  24%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########                             |  25%
#
# grpcio-1.42.0        | 1.9 MB    | ############################          |  76%
#
# grpcio-1.42.0        | 1.9 MB    | ############################3         |  77%
#
# grpcio-1.42.0        | 1.9 MB    | ############################6         |  77%
#
# grpcio-1.42.0        | 1.9 MB    | ############################9         |  78%
#
# grpcio-1.42.0        | 1.9 MB    | #############################2        |  79%
#
# grpcio-1.42.0        | 1.9 MB    | #############################5        |  80%
#
# grpcio-1.42.0        | 1.9 MB    | #############################8        |  81%
#
# grpcio-1.42.0        | 1.9 MB    | ##############################1       |  81%
#
# grpcio-1.42.0        | 1.9 MB    | ##############################4       |  82%
#
# grpcio-1.42.0        | 1.9 MB    | ##############################7       |  83%
#
# grpcio-1.42.0        | 1.9 MB    | ###############################       |  84%
#
# grpcio-1.42.0        | 1.9 MB    | ###############################3      |  85%
#
# grpcio-1.42.0        | 1.9 MB    | ###############################6      |  85%
#
# grpcio-1.42.0        | 1.9 MB    | ###############################9      |  86%
#
# grpcio-1.42.0        | 1.9 MB    | ################################2     |  87%
#
# grpcio-1.42.0        | 1.9 MB    | ################################5     |  88%
#
# grpcio-1.42.0        | 1.9 MB    | ################################8     |  89%
#
# grpcio-1.42.0        | 1.9 MB    | #################################1    |  90%
#
# grpcio-1.42.0        | 1.9 MB    | #################################4    |  90%
#
# grpcio-1.42.0        | 1.9 MB    | #################################7    |  91%
#
# grpcio-1.42.0        | 1.9 MB    | ##################################    |  92%
#
# grpcio-1.42.0        | 1.9 MB    | ##################################3   |  93%
#
# grpcio-1.42.0        | 1.9 MB    | ##################################6   |  94%
#
# grpcio-1.42.0        | 1.9 MB    | ##################################9   |  94%
#
# grpcio-1.42.0        | 1.9 MB    | ###################################2  |  95%
#
# grpcio-1.42.0        | 1.9 MB    | ###################################5  |  96%
#
# grpcio-1.42.0        | 1.9 MB    | ###################################8  |  97%
#
# grpcio-1.42.0        | 1.9 MB    | ####################################1 |  98%
#
# grpcio-1.42.0        | 1.9 MB    | ####################################4 |  99%
#
# grpcio-1.42.0        | 1.9 MB    | ####################################7 |  99%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########1                            |  25%
#
# grpcio-1.42.0        | 1.9 MB    | ##################################### | 100%
#
# grpcio-1.42.0        | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# jsonpointer-2.1      | 9 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# jsonpointer-2.1      | 9 KB      | ##################################### | 100%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########1                            |  25%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########2                            |  25%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########2                            |  25%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########3                            |  25%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########3                            |  25%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########4                            |  26%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########5                            |  26%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########5                            |  26%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########6                            |  26%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########6                            |  26%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########7                            |  26%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########7                            |  26%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########8                            |  27%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########8                            |  27%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########9                            |  27%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #########9                            |  27%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########                            |  27%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########                            |  27%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########1                           |  27%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########1                           |  28%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########3                           |  28%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########3                           |  28%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########4                           |  28%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########4                           |  28%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########5                           |  29%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########6                           |  29%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########7                           |  29%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########8                           |  29%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########9                           |  30%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########9                           |  30%
# daal4py-2023.1.1     | 10.8 MB   | ###########                           |  30%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########1                          |  30%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########1                          |  30%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########2                          |  30%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########2                          |  30%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########3                          |  31%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########3                          |  31%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########4                          |  31%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########4                          |  31%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########5                          |  31%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########5                          |  31%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########6                          |  31%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########6                          |  32%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########7                          |  32%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########7                          |  32%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########9                          |  32%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########9                          |  32%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############                          |  32%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############                          |  33%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############1                         |  33%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############1                         |  33%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############2                         |  33%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############2                         |  33%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############3                         |  33%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############3                         |  33%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############4                         |  34%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############4                         |  34%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############5                         |  34%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############5                         |  34%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############6                         |  34%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############7                         |  34%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############7                         |  34%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############8                         |  35%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############8                         |  35%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############9                         |  35%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############9                         |  35%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############                         |  35%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############                         |  35%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############1                        |  35%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #6                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #6                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ##############################8       |  83%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####3                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ###############################       |  84%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####3                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ###############################2      |  85%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####3                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ###############################4      |  85%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########################8           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####3                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ###############################6      |  86%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########################9           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ###############################9      |  86%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##########################9           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ################################1     |  87%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ################################3     |  87%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ################################5     |  88%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####5                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ################################7     |  88%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####5                                |  15%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####5                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####9                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ####################################6 |  99%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | #####9                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################2         |  76%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################2         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######                                |  16%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######1                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################5         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######1                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################5         |  77%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################6         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######1                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################6         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######1                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################7         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######2                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######3                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ############################9         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######3                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######3                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################         |  79%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######3                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######4                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######4                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################2        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######4                               |  17%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######4                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################4        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######5                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######5                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################5        |  80%
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######6                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# mpich-4.1.1          | 23.8 MB   | ######6                               |  18%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | #############################9        |  81%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##############################        |  81%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##############################1       |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# grpc-cpp-1.46.1      | 2.8 MB    | ##################################### | 100%
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##############################1       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# daal4py-2023.1.1     | 10.8 MB   | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# CancelledError()
# CancelledError()
# CancelledError()
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/osx-64/mpich-4.1.1-hc226d05_0.conda>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CancelledError()
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/osx-64/daal4py-2023.1.1-py39h01d92e1_0.conda>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/osx-64/libprotobuf-3.20.3-hfff2838_0.conda>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/noarch/keras-preprocessing-1.1.2-pyhd3eb1b0_0.conda>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://repo.anaconda.com/pkgs/main/osx-64/tensorboard-data-server-0.6.1-py39h7242b5c_0.conda>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip freeze | grep bcolz
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda bcolz
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - bcolz -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#
# Your python: python=3.9
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install python=3.6
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# Examining conflict for bottleneck seaborn imagecodecs networkx scikit-learn da-

# %%
from keras.applications.vgg16 import VGG16
